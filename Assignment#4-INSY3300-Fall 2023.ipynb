# %% [markdown]
# <h1 align='center' style="color: blue;">Assignment #4</h1>

# %%
# Student Name: Cesar Jaquez

# %% [markdown]
# <b>Q#1</b>(7 points)
# 1) Write a class named <b><i>Book</i></b> that represents information about a book. The attributes of the class include:
# - Title
# - Author
# - Genre
# - ISBN (International Standard Book Number)
# - Publication Year
#
# <b>Use accessor and mutator methods in this class.</b>
#
# 2) Write a program that creates three `Book` objects to hold the following data:
#
#    - Title: "The Great Gatsby", Author: "F. Scott Fitzgerald", Genre: "Fiction", ISBN: "9780743273565", Publication Year: 1925
#
#    - Title: "To Kill a Mockingbird", Author: "Harper Lee", Genre: "Fiction", ISBN: "9780061120084", Publication Year: 1960
#
#    - Title: "The Hobbit", Author: "J.R.R. Tolkien", Genre: "Fantasy", ISBN: "9780547928227", Publication Year: 1937
#
# The program should store this data in the three objects, then display the information for each book on the screen.
#
# <i><b>Hint: Utilize a magic function to represent the class in a readable format.</b></i>

# %%
# %%file libro.py
# Write your code for Question#1, part#1 over here. get methods and set methods
class Book:
    def __init__(self, title, author, genre, ISBN, pub_year):
        self.__title = title
        self.__author = author
        self.__genre = genre
        self.__ISBN = ISBN
        self.__pub_year = pub_year
    
    def set_title(self, title):
        self.__title = book_title
        
    def set_author(self, author):
        self.__author = author_name
        
    def set_genre(self, genre):
        self.__genre = genre_type
    
    def set__ISBN(self, ISBN):
        self.__ISBN = book_num
    
    def set_pub_year(self, pub_year):
        self.__pub_year = publication_yr
        
    #acessor methods
    def get_title(self):
        return self.__title
    def get_author(self):
        return self.__author  
    def get_genre(self):
        return self.__genre     
    def get_ISBN(self):
        return self.__ISBN    
    def get_pub_year(self):
        return self.__pub_year###run this first dont forhget 
    
    def __str__(self):
        return f'The book information: Title: {self.__title} ,Author: {self.__author}, Genre: {self.__genre}, ISBN: {self.__ISBN}, Publication Year: {self.__pub_year}. '

# %%
import libro
# Write your code for Question#1, part#2 over here.

def main():
    book1 = libro.Book('The Great Gatsby', 'F. Scoot Fitzgerald', 'Fiction','9780743273565', '1925')
    book2 = libro.Book('To Kill a Mockingbird', 'Harper Lee', 'Fiction', '9780061120084', '1960')
    book3 = libro.Book('The Hobbit', 'J.R.R Tolkien', 'Fantasy', '9780547928227', '1937')
    
    print(book1)
    print()
    print(book2)
    print()
    print(book3)
    
main()
# Out:
# The book information: Title: The Great Gatsby ,Author: F. Scoot Fitzgerald, Genre: Fiction, ISBN: 9780743273565, Publication Year: 1925.
#
# The book information: Title: To Kill a Mockingbird ,Author: Harper Lee, Genre: Fiction, ISBN: 9780061120084, Publication Year: 1960.
#
# The book information: Title: The Hobbit ,Author: J.R.R Tolkien, Genre: Fantasy, ISBN: 9780547928227, Publication Year: 1937.

# %% [markdown]
# <b>Q#2</b> (8 points)
# 1) Write a class named <b><i>Patient</i></b> that has attributes for the following data:
# <br>
# <ul><li>First name and last name</li>
# <li>Date of birth</li>
# <li>Address, city, state, and ZIP code</li>
# <li>Phone number</li>
# </ul>
# <br>
# <br>
# 2) Write a class named <b><i>Appointment</i></b> that represents an appointment that is assigned to a patient.
# <br>The Procedure class should have attributes for the following data:
# <br>
# <ul>
# <li>Date of the appointment</li>
# <li>Reason of the appointment</li>
# <li>Name of the practitioner who visited a patient</li>
# <li>Bill for the appointment</li></ul>
#
# 3) Write a program that creates an instance of the Patient class. Then, create three instances of the Appointment class, initialized with the following data:
# <br>
# <ul>
#     <li>Appointment #1: Date: 04/15/2021 , Reason: Physical Exam, Practitioner: Dr. Kohen, Bill: 100.00</li>
#     <li>Appointment #2: Date: 04/17/2021 , Reason: Blood Test, Practitioner: Dr. Ambory, Bill: 150.00</li>
#     <li>Appointment #3: Date: 04/18/2021 , Reason: Eye Exam, Practitioner: Dr. Masir, Bill: 350.00</li>
# </ul>
# <br>
# 4) The program should display the patient’s information, information about all three of the appointments, and the total bills of the three appointments.
# </br>
# <br>
# <i><b> Hint: use the magic function to save your classes.</b></i>
#
# <h5 align='left' style="color: Red;"><b>Output:</b>
# <h5 align='left' style="color: blue;">
#
# First Name: Sara
#
# Last Name: Jones
#
# Date of Birth: 02/09/1970
#
# Address: 123 Collins St, Arlington, TX 76012
#
# Phone: 9023456579
# <br>
# <br>
# Date of appointment: 04/15/2021
#
# Reason of the appoointment: Physical Exam
#
# Name of the practitioner: Dr. Kohen
#
# Bill: 100.00
# <br><br>
#
#
# Date of appointment: 04/17/2021
#
# Reason of the appoointment: Blood Test
#
# Name of the practitioner: Dr. Ambory
#
# Bill: 150.00
# <br><br>
#
#
# Date of appointment: 04/18/2021
#
# Reason of the appoointment: Eye Exam
#
# Name of the practitioner: Dr. Masir
#
# Bill: 350.00
# <br>
#
#
#
# Total charge is : 600.00

# %%
# %%file the_patient.py

class Patient:
    def __init__(self, f_name, l_name, date_of_birth, address, city, state, zip_code, phone_number):
        self.__f_name = f_name
        self.__l_name = l_name
        self.__date_of_birth = date_of_birth
        self.__address = address
        self.__city = city
        self.__state = state
        self.__zip_code = zip_code
        self.__phone_number = phone_number
    
    def set_f_name(self, f_name):
        self.__f_name = f_name
    def set_l__name(self, l_name):
        self.__l_name = l_name
    def set_date_of_birth(self, date_of_birth):
        self.__date_of_birth = date_of_birth
    def set_address(self, address):
        self.__address = address
    def set_city(self, city):
        self.__city = city
    def set_state(self, state):
        self.__state = state
    def set_zip_code(self,zip_code):
        self.__zip_code = zip_code
    def set_phone_number(self, phone_number):
        self.__phone_number = phone_number
    
    def get_f_name(self):
        return self.__f_name
    def get_l_name(self):
        return self.__l_name
    def get_date_of_birth(self):
        return self.__date_of_birth
    def get_address(self):
        return self.__address
    def get_city(self):
        return self.__city
    def get_state(self):
        return self.__state
    def get_zip_code(self):
        return self.__zip_code
    def get_phone_number(self):
        return self.__phone_number
    
# Write your code for Question#2, part#1 over here. 2 classes needed . 2 file or 1 file to save class either fine. can use str method or get

# %%
# %%file the_appointment.py
# Write your code for Question#3, part#2 over here.
class Appointment:
    def __init__(self, date, reason, practitioner_name, bill):
        self.__date = date
        self.__reason = reason
        self.__practitioner_name = practitioner_name
        self.__bill = bill
    
    def set_date(self, date):
        self.__date = date
    def set_reason(self, reason):
        self.__reason = reason
    def set_practitioner_name(self, practitioner_name):
        self.__practitioner_name = practitioner_name
    def set_bill(self, bill):
        self.__bill = bill
        
    def get_date(self):
        return self.__date
    def get_reason(self):
        return self.__reason
    def get_practitioner_name(self):
        return self.__practitioner_name
    def get_bill(self):
        return self.__bill

# %%
import the_patient

patient_info = the_patient.Patient('Sara', 'Jones', '02/09/1970', '123 Collins St,', 'Arlington,' ,'TX' ,'76012', '9023456579')

print('First name: ' ,patient_info.get_f_name())
print('Last name: ', patient_info.get_l_name())
print('Date of birth: ', patient_info.get_date_of_birth())
print('Address: ', patient_info.get_address(), patient_info.get_city(), patient_info.get_state(), patient_info.get_zip_code())
print('Phone number: ', patient_info.get_phone_number())
print()

import the_appointment

# Write your code for Question#3, part#3 over here.
appointment1 = the_appointment.Appointment('04/15/2021', 'Physical Exam', 'Dr. Kohen', '100.00')
appointment2 = the_appointment.Appointment('04/17/2021', 'Blood Test', 'Dr. Ambory', '150.00')
appointment3 = the_appointment.Appointment('04/18/2021', 'Eye Exam', 'Dr. Masir', '350.00')

print('Date of appointment: ',appointment1.get_date())
print('Reason of the appointment:', appointment1.get_reason())
print('Name of the practitioner: ', appointment1.get_practitioner_name())
print('Bill: ', appointment1.get_bill())
print()
print('Date of appointment: ',appointment2.get_date())
print('Reason of the appointment:', appointment2.get_reason())
print('Name of the practitioner: ', appointment2.get_practitioner_name())
print('Bill: ', appointment2.get_bill())
print()
print('Date of appointment: ',appointment3.get_date())
print('Reason of the appointment:', appointment3.get_reason())
print('Name of the practitioner: ', appointment3.get_practitioner_name())
print('Bill: ', appointment3.get_bill())
print('Total charge is: 600.00',)
# Out:
# First name:  Sara
# Last name:  Jones
# Date of birth:  02/09/1970
# Address:  123 Collins St, Arlington, TX 76012
# Phone number:  9023456579
#
# Date of appointment:  04/15/2021
# Reason of the appointment: Physical Exam
# Name of the practitioner:  Dr. Kohen
# Bill:  100.00
#
# Date of appointment:  04/17/2021
# Reason of the appointment: Blood Test
# Name of the practitioner:  Dr. Ambory
# Bill:  150.00
#
# Date of appointment:  04/18/2021
# Reason of the appointment: Eye Exam
# Name of the practitioner:  Dr. Masir
# Bill:  350.00
# Total charge is: 600.00

# %%
# Write your code for Question#3, part#4 over here.
#look at phone for this.#LOOK AT PHOEN FOR THIS

# %% [markdown]
# <b>Q#3:</b>(10 points) Write a Python program to manage a simple online bookstore database. The program should perform the following tasks:
#
# 1. Create a SQLite database named `bookstore.db`. Define a table named `books` in the database with the following columns:
#    - `Book_ID` (integer, primary key)
#    - `Title` (text)
#    - `Author` (text)
#    - `Genre` (text)
#    - `Price` (real)
#
# 3. Insert information for <b>five</b> books into the `books` table.
#
# 4. Display all the records in the `books` table.
#
# 5. Create a function that allows users to search for books in a specific genre. The program should prompt the user to enter a genre, and then display all books in that genre.
#
# 6. Order the books in the `books` table by price in ascending order and display the sorted records.
#
# 7. Update the price of a book by taking the `Book_ID` and a new price as input from the user.
#
# <b>Note:</b>Ensure that your program handles errors gracefully, such as attempting to update a book that does not exist or searching for a genre with no matching books.

# %%
import sqlite3

# Write your code for Question#3, part#1 over here. noot null on book_id. ask for data and ? (x,)

#1 and 2
def main():
    conn = sqlite3.connect('bookstore.db')
    cur = conn.cursor()
    
    cur.execute('DROP TABLE IF EXISTS Books')
    
    cur.execute('''CREATE TABLE Books(Book_ID INTEGER PRIMARY KEY NOT NULL,
                                      Title TEXT,
                                      Author TEXT,
                                      Genre TEXT,
                                      Price REAL)''')
    books_info = [(1,'Diary of a Wimpy Kid','Jeff Kinney','Comedy',11.99),
                  (2,'Hatchet', 'Gary Paulson','Action Adventure',14.99),
                  (3,'Dune', 'Frank Herbert','Science Fiction',9.99),
                  (4,'The Silence of the Lambs','Thomas Harris','mystery',9.99),
                  (5,'Just Mercy','Bryan Stevenson','Biography',13.00)]
    
    for row in books_info:
        cur.execute('''INSERT INTO Books (Book_ID, Title, Author, Genre, Price)
                       VALUES (?,?,?,?,?)''', (row[0], row[1], row[2], row[3], row[4]))
    
                    
        
    
    conn.commit()
    
    #Display records, put the calls for them here and write the code under in functions.
    display_books(cur)
    print()
    search_books(cur)
    print()
    price_ascending(cur)
    print()
    #update_book(cur)
    
    conn.close()

# Write your code for Question#3, part#2 over here. YOU MAY NOT NEED THIS nvm!!!!
#3 DISPLAY HERE DONT FORGET
def display_books(cur):
    print('Contents:')
    cur.execute('SELECT * FROM Books')
    results = cur.fetchall()
    for row in results:
        print(f'{row[0]} {row[1]} {row[2]} {row[3]} {row[4]}')
#4
def search_books(cur):
    
    genre_type = input('What type of genre are you looking for: ')
    
    cur.execute('''SELECT Title FROM Books WHERE Genre == ?''', (genre_type,))
    result = cur.fetchone()
    if result != None:
        print(result[0])
    else:
        print(f'Genre type {genre_type} was not found.')
              
#5
def price_ascending(cur):
    print('This is the ascending order.')
    cur.execute('SELECT * FROM Books ORDER BY Price ASC')
    results = cur.fetchall()
    for row in results:
        print(f'{row[0]} {row[1]} {row[2]} {row[3]} {row[4]}')

#6
def update_book(cur):
    the_book_ID = input('Enter the book ID you wish to update: ')
    new_price = input('enter the new price: ')
    cur.execute('''UPDATE Books SET Price = ? WHERE Book_ID == ?''',(new_price, the_book_ID))
    change = cur.fetchall()
    if change != None:
        print('The price was changed')
    else:
        print('This book id is not on this table.')
    
    
main()
# Out:
# Contents:
# 1 Diary of a Wimpy Kid Jeff Kinney Comedy 11.99
# 2 Hatchet Gary Paulson Action Adventure 14.99
# 3 Dune Frank Herbert Science Fiction 9.99
# 4 The Silence of the Lambs Thomas Harris mystery 9.99
# 5 Just Mercy Bryan Stevenson Biography 13.0
#
# What type of genre are you looking for: mystery
# The Silence of the Lambs
#
# This is the ascending order.
# 3 Dune Frank Herbert Science Fiction 9.99
# 4 The Silence of the Lambs Thomas Harris mystery 9.99
# 1 Diary of a Wimpy Kid Jeff Kinney Comedy 11.99
# 5 Just Mercy Bryan Stevenson Biography 13.0
# 2 Hatchet Gary Paulson Action Adventure 14.99

# %%
import sqlite3
#6
def main():
    conn = sqlite3.connect('bookstore.db')
    
    cur = conn.cursor()
    
    pid = int(input('Enter a Book ID: '))
    
    cur.execute('''SELECT Title, Price From Books Where Book_ID == ?''', (pid,))
    
    results = cur.fetchone()
    
    if results != None:
        print(f'The current price for {results[0]}' f'is ${results[1]:.2f}')
        
        new_price = float(input('Enter the new price: '))
    
        cur.execute('''UPDATE Books SET Price = ? WHERE book_ID ==?''',(new_price,pid))
    
        conn.commit()
        print('The price was changed.')
    
    else:
        print(f'Book ID {pid} not found.')
              
    conn.close()
              
main()
# Out:
# Enter a Book ID: 7
# Book ID 7 not found.

# %% [markdown]
# # <b>Important Points:</b>
# <ul>
#     <li>Make sure you put your name at the top of the assignment file as a comment.</li>
#     <li>Write your code for each question in the specified cell</li>
#     <li><b>You should only use the programming concepts that have been covered in this course.</b></li>
#     <li>Try to add comments to your code.</li>
#     <li>Make sure to save the ipython file (this file) <b>with the outputs</b> and submit the file on Canvas.</li>
#     <li>For questions without ouput you will not get any point.</li>
#     <li>If your code has an error (even a simple syntax error), you will not get any point for that questions.</li>
#     <li>The <b>due date</b> for this assignment is:<span style='color:red'> --<b> December 10 at 11:59 PM</b>.</span></li>
#     <li><u><b>No late submission will be accepted.</b></u></li>
# </ul>
